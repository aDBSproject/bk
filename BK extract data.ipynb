# %%
### extractData for esm windows from edf files


import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import pyedflib
import numpy as np
from datetime import timedelta
from scipy.signal import decimate
import time
from os import listdir
from os.path import isfile, join

import os
path="/Users/jeroenhabets/Desktop/python_code/bradykinesia analysis"
os.chdir(path)

# change working path and get/download sensor data
# discuss: prepare ESM data file before using it; labels + combined items?

def loadESM(path):
    esm = df = pd.read_stata(path+'/data/PRDB_20190227T102701/SANPAR_BE.dta',convert_categoricals = False)
    esm = esm[['subjno', 'mood_well', 'mood_down', 'mood_fright', 'mood_tense', 'phy_sleepy', 'phy_tired',
           'mood_cheerf', 'mood_relax', 'thou_concent', 'pat_hallu', 'loc_where',
           'soc_who', 'soc_who02', 'soc_who03', 'act_what', 'act_what02',
           'act_what03', 'act_norpob', 'sanpar_been', 'sanpar_stil',
           'sanpar_spreken', 'sanpar_lopen', 'sanpar_tremor', 'sanpar_traag',
           'sanpar_stijf', 'sanpar_spann', 'sanpar_beweeg', 'sanpar_onoff',
           'sanpar_medic', 'beep_disturb', '_datetime', '_datetime_e', 'dayno_n', 'beepno_n']]
    esm['duration'] = esm['_datetime_e']-esm['_datetime']
    # rename to english
    esm = esm.rename(index=str,columns={'sanpar_been':'prob_mobility','sanpar_stil':'prob_stillness','sanpar_spreken':'prob_speech','sanpar_lopen':'prob_walking','sanpar_tremor':'tremor','sanpar_traag':'slowness','sanpar_stijf':'stiffness','sanpar_spann':'tension','sanpar_beweeg':'dyskinesia','sanpar_onoff':'onoff','sanpar_medic':'medic'})

# only selecting for test patients (110004, 110014, 110016, 110018)
  #  esm = esm[esm['subjno']==9009992]
    
    esm.loc[esm['subjno'].isin([9009992,9010002,9010004,9010006])]
   
    
    mapNames={}
    for i in range(25):
        mapNames[9009989+i]=110001+i

    esm['castorID'] = [mapNames[e] for e in esm['subjno']]
    return esm




# create list of files per L/R/chest from directory (mypath)
def getFileLists(localPath, subject):
    localPath = join(localPath, subject)
    leftSensors = ['13797','13799','13794','13806']
    rightSensors = ['13805','13801','13793', '13795']
    chestSensors = ['13804','13792','13803', '13796']

    


    bdffiles = [f for f in listdir(localPath) if isfile(join(localPath,f)) and f[0]!='_' and f[-3:] =='edf']
    #bdffiles are the files in mypath, not directories

    leftFiles = []
    rightFiles = []
    chestFiles = []

    for f in bdffiles:
        if f[0:5] in leftSensors:
            leftFiles.append(join(localPath,f))
        elif f[0:5] in rightSensors:
            rightFiles.append(join(localPath,f))
        elif f[0:5] in chestSensors:
            chestFiles.append(join(localPath,f))

    leftFiles=sorted(leftFiles)
    rightFiles=sorted(rightFiles)
    chestFiles=sorted(chestFiles)
    return leftFiles, rightFiles, chestFiles




def extractRawTrials(leftFiles,rightFiles,chestFiles,esmFrame,esmWindowLength=15,featureWindowLength=60):
    # Read in the three list of files
    #Process leftWristData
    leftWristDF=[]
    rightWristDF=[]
    chestDF=[]
    
    files = [leftFiles, rightFiles, chestFiles]
    trials = [[[] for _ in range(esmFrame.shape[0])],[[] for _ in range(esmFrame.shape[0])], [[] for _ in range(esmFrame.shape[0])]]
    identifiers = ['l', 'r', 'c']
    foundTrials = np.zeros((esmFrame.shape[0],3))
    for i, f in enumerate(files):
        for file in f:
            print(file)
            try:
                labels, timeStamps, data, sr = readData(file) ## as input instead: leftFiles
                if data.shape[1]<sr * featureWindowLength:
                    raise ValueError('File too short to proceed.')
            except:
                print('%s is broken' % file)
                continue
            data = pd.DataFrame(data.T,index=timeStamps)
            for beep in range(esmFrame.shape[0]):
                if foundTrials[beep,i]==1:
                    continue
                beepTime=esmFrame['_datetime'].iloc[beep] # Get the corresponding time
                timediff = np.min(np.abs(data.index-beepTime)) 
                # Find corresponding moment for beep time in the sensor data
                #print(timediff)
                if timediff>timedelta(minutes=esmWindowLength):
                # If corresponding time is too far off, remove beep
                #print("Couldn't find corresponding sensor data")
                    continue
                pos=np.argmin(np.abs(data.index-beepTime))
                # For the smallest time difference find the position in the sensor data
                if pos>esmWindowLength*windowLength*sr:
                    trials[i][beep] = data.iloc[pos-(int(esmWindowLength*windowLength*sr)):pos]
                    foundTrials[beep,i]=1

    keep = np.sum(foundTrials,axis=1)==3
    trialData = np.zeros((np.sum(keep),int(esmWindowLength*windowLength*sr), 3 * 6))
    counter =0
    for beep in range(esmFrame.shape[0]):
        if keep[beep]:
            temp = np.concatenate((trials[0][beep],trials[1][beep],trials[2][beep]),axis=1)
            trialData[counter,:,:]=temp
            counter+=1
    foundESM = esmFrame.iloc[keep,:]   
    return trialData,  foundESM





def readData(filename): 
    #Extract data
    f = pyedflib.EdfReader(filename)
    sr = f.getSampleFrequencies()[0]
    n = f.signals_in_file
    signal_labels = f.getSignalLabels()
    sigbufs = np.zeros((n, f.getNSamples()[0]))
    for i in np.arange(n):
        sigbufs[i, :] = f.readSignal(i)    
    #Get starting time
    #startingTime=f.getStartdatetime() #needs to be tested
    startingTime=filename[-19:-4]
    startingTime=pd.to_datetime(startingTime, format='%Y%m%d_%H%M%S', errors='ignore')
    #print(startingTime)
    sigbufs = decimate(sigbufs,downsampling,axis=1)
    sr=sr/downsampling
    timeStamps=pd.date_range(start=startingTime,periods=sigbufs.shape[1],freq='%d ms' % (1000/sr))
    return signal_labels, timeStamps, sigbufs, sr





def alignFeaturesESM(listOfDF,esmFrame,esmColumns,esmWindowLength=15):
    
    combinedColumns=esmColumns
    for featureFrame in listOfDF:
        combinedColumns= combinedColumns + featureFrame.keys().tolist()  
    esmFeatures=pd.DataFrame(columns=combinedColumns) # Create new empty dataframe with feature and esm columns

    hop=np.mean(np.diff(listOfDF[0].index))
    for beep in range(esmFrame.shape[0]): #Loop through all the ESM Beeps
        beepTime=esmFrame['_datetime'].iloc[beep] # Get the corresponding time
        
        esmData=np.matlib.repmat(esmFrame.iloc[beep][esmColumns],esmWindowLength,1)
        combined=esmData
        
        subIndex=[beepTime-hop*t for t in range(esmWindowLength)][::-1]
        for featureFrame in listOfDF:
        
        
            timediff = np.min(np.abs(featureFrame.index-beepTime)) 
            # Find corresponding moment for beep time in the sensor data
            #print(timediff)
            if timediff>timedelta(minutes=esmWindowLength):
                # If corresponding time is too far off, remove beep
                #print("Couldn't find corresponding sensor data")
                continue
            pos=np.argmin(np.abs(featureFrame.index-beepTime))
            # For the smallest time difference find the position in the sensor data
            if pos>esmWindowLength:
                featColumns=featureFrame.keys().tolist() #The names of the features                
                featData=featureFrame.iloc[pos-esmWindowLength:pos][featColumns].values
                # Get corresponding timestamps
                
                # Repeat ESM data for each data point in the window
                combined=np.concatenate((combined,featData),axis=1)
                #Combine ESM & feature data
        if combined.shape[1]==len(combinedColumns):
            esmFeatures=esmFeatures.append(pd.DataFrame(combined,columns=combinedColumns,index=subIndex))
                #Append combined data to the dataframe
    return esmFeatures


if __name__ == '__main__':

    path = "/Users/jeroenhabets/Desktop/python_code/bradykinesia analysis"
    downsampling=2
    localPath = '/Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/'
    outPath = '/Users/jeroenhabets/Desktop/python_code/bradykinesia analysis'
    featureWindowLength=60
    windowLength=60
    esmWindowLength=15

    esm = loadESM(path)
    
    #allSubs = ['110001','110002','110003','110004','110005','110006','110007','110008','110009','110010','110011','110013','110014','110015','110016','110017','110018','110019','110020','110021']
    allSubs = ['110004','110014','110016','110018'] 
    for subject in allSubs:
        leftFiles, rightFiles, chestFiles = getFileLists(localPath, subject)
        t=time.time()
        trialData,selectedESM = extractRawTrials(leftFiles,rightFiles,chestFiles,esm[esm['castorID']==int(subject)])
        print(time.time()-t)
        print(trialData.shape)
        print(selectedESM.shape)
        np.save(join(outPath,subject + '_trials.npy'),trialData.astype(np.float32))
        selectedESM.to_csv(join(outPath, subject + '_esm.csv'),index=False)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20180921_071042.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20180922_072926.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20180923_073750.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20180924_072230.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20180925_071531.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20180926_071407.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20180927_071115.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20180928_075435.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20180929_114801.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20180930_075043.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20181001_071440.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20181002_063137.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20181003_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20181003_063750.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13794_20181004_071826.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20180921_071043.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20180922_072927.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20180923_073751.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20180924_072233.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20180925_071531.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20180926_071410.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20180927_071119.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20180928_075439.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20180929_114808.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20180930_075044.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20181001_071453.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20181002_063147.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20181003_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20181003_063755.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13793_20181004_071834.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20180921_071043.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20180922_072927.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20180923_073751.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20180924_072233.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20180925_071533.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20180926_071410.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20180927_071119.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20180928_075440.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20180929_114815.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20180930_075044.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20181001_071449.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20181002_063145.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20181003_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20181003_063758.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110004/13803_20181004_071834.edf
# 589.2274668216705
# (77, 90000, 18)
# (77, 37)
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181128_074026.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181128_230359.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181128_230359.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181129_073352.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181130_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181130_073407.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181201_073915.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181202_073600.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181203_073609.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181204_073606.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181205_073639.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181206_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181206_000110.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181206_000110.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181206_073016.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181207_073428.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181207_234453.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181207_234453.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181208_075047.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181208_233755.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181208_233755.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181209_073818.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181210_073355.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13794_20181211_073525.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181128_074027.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181128_230400.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181128_230400.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181129_073353.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181130_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181130_073409.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181201_073917.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181202_073446.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181203_073612.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181203_225357.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181203_225357.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181204_073445.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181205_073643.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181206_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181206_073020.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181207_073434.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181208_075053.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181208_233801.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181208_233801.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181209_073824.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181210_073401.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13793_20181211_073452.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181128_074026.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181128_230400.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181128_230400.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181129_073353.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181130_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181130_073409.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181201_073917.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181202_073512.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181203_073612.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181204_073610.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181205_073643.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181206_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181206_073021.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181207_073434.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181208_075053.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181208_233801.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181208_233801.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181209_073824.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181210_073401.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110014/13803_20181211_073601.edf
# 13016.20887708664
# (85, 90000, 18)
# (85, 37)
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190108_074403.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190109_073810.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190110_074032.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190111_073613.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190111_214108.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190111_214108.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190112_093143.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190113_100217.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190114_074223.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190114_224013.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190114_224013.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190114_224016.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190114_224016.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190114_224019.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190114_224019.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190114_224021.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190114_224021.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190115_074000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190116_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190117_074041.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190117_074041.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190117_074104.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190118_074139.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190118_221614.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190118_221614.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190118_221617.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190118_221617.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190119_093044.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190120_102741.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190120_220830.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190120_220830.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190120_220832.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190120_220832.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13799_20190121_073836.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190108_074403.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190109_073812.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190110_074031.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190111_073609.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190111_214107.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190111_214107.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190112_093142.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190113_100216.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190114_074221.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190115_073958.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190116_074047.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190117_074050.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190118_074136.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190119_093042.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190120_102728.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13801_20190121_073849.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190108_074403.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190109_073811.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190110_074029.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190111_073610.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190111_214104.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190111_214104.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190112_093139.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190113_100208.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190114_074217.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190115_073953.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190116_074046.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190117_074031.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190118_074125.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190119_093033.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190120_102747.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110016/13792_20190121_073857.edf
# 1588.7970187664032
# (77, 90000, 18)
# (77, 37)
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190109_083149.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190110_092745.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190111_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190111_061000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190112_084509.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190113_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190113_100711.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190114_072923.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190114_212039.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190114_212039.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190115_090812.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190116_081145.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190117_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190117_074510.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190118_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190118_140829.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190119_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190119_065724.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190120_081758.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190121_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190121_071610.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190122_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13797_20190122_092104.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190109_083149.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190110_092745.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190111_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190111_060959.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190112_084508.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190113_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190113_100710.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190114_072921.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190114_212037.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190114_212037.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190115_090810.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190116_081142.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190117_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190117_074508.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190118_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190118_140826.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190119_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190119_065720.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190120_081754.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190121_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190121_071606.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190122_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190122_092102.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190122_215727.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13805_20190122_215727.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190109_083149.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190110_092745.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190111_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190111_060959.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190112_084507.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190113_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190113_100709.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190114_072918.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190114_212036.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190114_212036.edf is broken
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190115_090809.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190116_081142.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190117_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190117_074507.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190118_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190118_140825.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190119_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190119_065719.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190120_081753.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190121_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190121_071605.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190122_000000.edf
# /Users/jeroenhabets/Desktop/python_code/bradykinesia analysis/data/110018/13804_20190122_092056.edf
# 1285.118800163269
# (62, 90000, 18)
# (62, 37)
